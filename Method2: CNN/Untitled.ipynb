# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
import tensorflow as tf



train_images = np.empty([64594, 105, 85, 3], dtype=np.uint8)
train_labels = np.arange(64594)
train_labels = np.expand_dims(train_labels, axis=1)

test_images = np.empty([2875, 101,85,3], dtype=np.uint8)
test_labels = np.arange(2785)
test_labels = np.expand_dims(test_labels, axis=1)

test_images_path = "/Users/zhoushaoyang/Downloads/counting/test/images/"
train_images_path = "/Users/zhoushaoyang/Downloads/counting/train/images/"


for img in os.listdir(train_images_path):
    try:
        img_array1 = cv2.imread(os.path.join(train_images_path,img))
        Img_array1 = cv2.resize(img_array1,(101,85))
    except Exception as e:
        pass

train_images=[Img_array1]

for img in os.listdir(test_images_path):
    try:
        img_array2 = cv2.imread(os.path.join(test_images_path,img))
        Img_array2 = cv2.resize(img_array2, (101,85))
    except Exception as e:
        pass
test_images=[Img_array2]

#print(img_array1)
#print(img_array2)


#model = models.sequential()
#model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
#model.add(layers.MaxPooling2D((2, 2)))
#model.add(layers.Conv2D(64, (3, 3), activation='relu'))
#model.add(layers.MaxPooling2D((2, 2)))
#model.add(layers.Conv2D(64, (3, 3), activation='relu'))

#model.summary()
#model.add(layers.Flatten())
#model.add(layers.Dense(64, activation='relu'))
#model.add(layers.Dense(10))

#model.compile(optimizer='adam',
              #loss=tf.kersa.losses.SparseCategoricalCrossentropy(from_logits=True),
              #metrics=['accuracy'])
#history = model.fit(train_images,train_labels,ellipsis=64594,
                    #validation_data=(test_images,test_labels)
#def loadImages(data_path):
#    imagesList = listdir(data_path)
#    loadImages = []
#    for image in imagesList:
#        img = PImage.open(data_path + image)
#        loadImages.append(img)
#    return loadImages
#imgs = loadImages(data_path)
#for i in range(64594):
#    img_name = data_path + "_%05d" % i + ".png"
#    train_images[i, :, :, :] = plt.imread(img_name)
#plt.figure(figsize=(10, 4))
#for i in range(64594):
#    plt.subplot(2, 5, i+1)
#    plt.xticks([])
#    plt.yticks([])
#    plt.grid(False)
#    plt.imshow(train_images[i, :, :, :], )
#plt.show()
